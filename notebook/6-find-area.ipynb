# %%
# set PATH
import sys
sys.path.insert(0, '../src')

# %%
from query import find_area_baseline, get_heatmap

variable = "2m_temperature"
start_datetime = "2020-01-01 00:00:00"
end_datetime = "2023-12-31 23:00:00"
# Greenland
max_lat = 85
min_lat = 60
min_lon = -70
max_lon = -10
heatmap_aggregation_method = "mean"

filter_predicate = ">"
filter_value = 260

find_area_baseline(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    min_lat=min_lat,
    max_lat=max_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    heatmap_aggregation_method=heatmap_aggregation_method,
    filter_predicate=filter_predicate,
    filter_value=filter_value,
)
# Out:
# ******************
# whole year
# 2020
# 2021
# 2022
# 2023
# whole month
# whole day
# whole hour
# <xarray.Dataset> Size: 26kB
# Dimensions:    (latitude: 101, longitude: 241)
# Coordinates:
#   * latitude   (latitude) float32 404B 85.0 84.75 84.5 84.25 ... 60.5 60.25 60.0
#   * longitude  (longitude) float32 964B -70.0 -69.75 -69.5 ... -10.25 -10.0
# Data variables:
#     t2m        (latitude, longitude) bool 24kB False False False ... True True

# %%
get_heatmap(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    min_lat=min_lat,
    max_lat=max_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    heatmap_aggregation_method=heatmap_aggregation_method,
)
# Out:
# ******************
# whole year
# 2020
# 2021
# 2022
# 2023
# whole month
# whole day
# whole hour
# <xarray.Dataset> Size: 196kB
# Dimensions:    (latitude: 101, longitude: 241)
# Coordinates:
#   * latitude   (latitude) float32 404B 85.0 84.75 84.5 84.25 ... 60.5 60.25 60.0
#   * longitude  (longitude) float32 964B -70.0 -69.75 -69.5 ... -10.25 -10.0
# Data variables:
#     t2m        (latitude, longitude) float64 195kB 258.8 258.8 ... 282.3 282.3
