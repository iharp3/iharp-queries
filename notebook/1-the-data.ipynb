# %% [markdown]
# # File directory

# %%
base_dir = '/data/era5'
raw_data_dir = f'{base_dir}/raw'
raw_temperature_dir = f'{raw_data_dir}/2m_temperature'

# %% [markdown]
# # Data shape

# %%
import xarray as xr

ds = xr.open_dataset(f'{raw_temperature_dir}/2m_temperature-2022.nc')
ds
# Out:
# <xarray.Dataset> Size: 73GB
# Dimensions:    (longitude: 1440, latitude: 721, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12-31T23:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float64 73GB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-06-03 17:46:01 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
# To view the shape
ds.chunk().t2m
# Out:
# <xarray.DataArray 't2m' (time: 8760, latitude: 721, longitude: 1440)> Size: 73GB
# dask.array<xarray-t2m, shape=(8760, 721, 1440), dtype=float64, chunksize=(8760, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 70kB 2022-01-01 ... 2022-12-31T23:00:00
# Attributes:
#     units:      K
#     long_name:  2 metre temperature

# %% [markdown]
# # Data accessing

# %%
ds['t2m'][0]
# Out:
# <xarray.DataArray 't2m' (latitude: 721, longitude: 1440)> Size: 8MB
# [1038240 values with dtype=float64]
# Coordinates:
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     time       datetime64[ns] 8B 2022-01-01
# Attributes:
#     units:      K
#     long_name:  2 metre temperature

# %%
ds['t2m'][0].compute()
# Out:
# <xarray.DataArray 't2m' (latitude: 721, longitude: 1440)> Size: 8MB
# array([[248.43900427, 248.43900427, 248.43900427, ..., 248.43900427,
#         248.43900427, 248.43900427],
#        [247.89420671, 247.89420671, 247.89622448, ..., 247.89218895,
#         247.89218895, 247.89420671],
#        [247.62987901, 247.62987901, 247.63189678, ..., 247.62584347,
#         247.62584347, 247.62786124],
#        ...,
#        [250.13594777, 250.13796554, 250.13998331, ..., 250.1278767 ,
#         250.12989447, 250.13393001],
#        [250.69285194, 250.69486971, 250.69486971, ..., 250.68881641,
#         250.69083417, 250.69083417],
#        [250.74934947, 250.74934947, 250.74934947, ..., 250.74934947,
#         250.74934947, 250.74934947]])
# Coordinates:
#   * longitude  (longitude) float32 6kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     time       datetime64[ns] 8B 2022-01-01
# Attributes:
#     units:      K
# ...

# %%
ds.sel(
    latitude=slice(80, 30), 
    longitude=slice(0, 50), 
    time=slice('2022-02-01', '2022-02-28')
)
# Out:
# <xarray.Dataset> Size: 217MB
# Dimensions:    (longitude: 201, latitude: 201, time: 672)
# Coordinates:
#   * longitude  (longitude) float32 804B 0.0 0.25 0.5 0.75 ... 49.5 49.75 50.0
#   * latitude   (latitude) float32 804B 80.0 79.75 79.5 79.25 ... 30.5 30.25 30.0
#   * time       (time) datetime64[ns] 5kB 2022-02-01 ... 2022-02-28T23:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float64 217MB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-06-03 17:46:01 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
ds.sel(
    latitude=slice(80, 30), 
    longitude=slice(0, 50), 
    time=slice('2022-02-01', '2022-02-28')
).compute()
# Out:
# <xarray.Dataset> Size: 217MB
# Dimensions:    (longitude: 201, latitude: 201, time: 672)
# Coordinates:
#   * longitude  (longitude) float32 804B 0.0 0.25 0.5 0.75 ... 49.5 49.75 50.0
#   * latitude   (latitude) float32 804B 80.0 79.75 79.5 79.25 ... 30.5 30.25 30.0
#   * time       (time) datetime64[ns] 5kB 2022-02-01 ... 2022-02-28T23:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float64 217MB 262.5 262.8 ... 289.4
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-06-03 17:46:01 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
