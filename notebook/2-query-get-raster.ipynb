# %%
# set PATH
import sys
sys.path.insert(0, '../src')

# %%
from query import get_raster

variable = "2m_temperature"
start_datetime = "2020-01-01 00:00:00"
end_datetime = "2023-12-31 23:00:00"
time_resolution = "year"
time_agg_method = "mean"
# Greenland
max_lat = 85
min_lat = 60
min_lon = -70
max_lon = -10

get_raster(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    time_resolution=time_resolution,
    time_agg_method=time_agg_method,
    min_lat=min_lat,
    max_lat=max_lat,
    min_lon=min_lon,
    max_lon=max_lon,
)
# Out:
# ['/data/era5/agg//2m_temperature/2m_temperature-year-mean.nc']
# <xarray.Dataset> Size: 780kB
# Dimensions:    (time: 4, latitude: 101, longitude: 241)
# Coordinates:
#   * longitude  (longitude) float32 964B -70.0 -69.75 -69.5 ... -10.25 -10.0
#   * latitude   (latitude) float32 404B 85.0 84.75 84.5 84.25 ... 60.5 60.25 60.0
#   * time       (time) datetime64[ns] 32B 2020-12-31 2021-12-31 ... 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 779kB 259.1 259.1 ... 282.5
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-30 17:50:29 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
