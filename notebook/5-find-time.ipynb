# %%
# set PATH
import sys
sys.path.insert(0, '../src')

# %%
from query import find_time_baseline, get_timeseries, find_time_equal

variable = "2m_temperature"
start_datetime = "2020-01-01 00:00:00"
end_datetime = "2023-12-31 23:00:00"
time_resolution = "hour"
time_agg_method = "max"
# Greenland
max_lat = 85
min_lat = 60
min_lon = -70
max_lon = -10

time_series_aggregation_method = "max"
filter_predicate = "=="
"""
Test Cases:
    Year:
        Max: 299.47383242156104
        Min: 210.61720203928078
        Mean: 262.3857164843415
    Month:
        Max: 284.42105749018015, 293.7703247660141
        Min: 217.81991689304772, 218.12162920562238
        Mean: 258.0404686365779, 229.0473932651394
    Day:
        Max: 210.61720203928078
        Min: 223.70254767751862, 220.85027046810612
    Hour:
        Max: 317.20237690953525
"""
filter_value = 299.47383242156104

find_time_baseline(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    time_resolution=time_resolution,
    time_agg_method=time_agg_method,
    max_lat=max_lat,
    min_lat=min_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    time_series_aggregation_method=time_series_aggregation_method,
    filter_predicate=filter_predicate,
    filter_value=filter_value,
)
# Out:
# ['/data/era5/raw/2m_temperature/2m_temperature-2020.nc', '/data/era5/raw/2m_temperature/2m_temperature-2021.nc', '/data/era5/raw/2m_temperature/2m_temperature-2022.nc', '/data/era5/raw/2m_temperature/2m_temperature-2023.nc']
# <xarray.Dataset> Size: 316kB
# Dimensions:  (time: 35064)
# Coordinates:
#   * time     (time) datetime64[ns] 281kB 2020-01-01 ... 2023-12-31T23:00:00
# Data variables:
#     t2m      (time) bool 35kB False False False False ... False False False

# %%
get_timeseries(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    time_resolution=time_resolution,
    time_agg_method=time_agg_method,
    max_lat=max_lat,
    min_lat=min_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    time_series_aggregation_method=time_series_aggregation_method
)
# Out:
# ['/data/era5/raw/2m_temperature/2m_temperature-2020.nc', '/data/era5/raw/2m_temperature/2m_temperature-2021.nc', '/data/era5/raw/2m_temperature/2m_temperature-2022.nc', '/data/era5/raw/2m_temperature/2m_temperature-2023.nc']
# <xarray.Dataset> Size: 561kB
# Dimensions:  (time: 35064)
# Coordinates:
#   * time     (time) datetime64[ns] 281kB 2020-01-01 ... 2023-12-31T23:00:00
# Data variables:
#     t2m      (time) float64 281kB 283.4 283.5 283.5 283.5 ... 282.0 281.9 282.0

# %%
find_time_equal(
    variable=variable,
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    time_resolution=time_resolution,
    time_agg_method=time_agg_method,
    max_lat=max_lat,
    min_lat=min_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    time_series_aggregation_method=time_series_aggregation_method,
    filter_value=filter_value,
)
# Out:
# ******************
# whole year
# 2020
# 2021
# 2022
# 2023
# whole month
# whole day
# whole hour
# ******************
# whole year
# whole month
# whole day
# 2020-07-16
# whole hour
# 2020-07-16 00:00:00
# 2020-07-16 01:00:00
# 2020-07-16 02:00:00
# 2020-07-16 03:00:00
# 2020-07-16 04:00:00
# 2020-07-16 05:00:00
# 2020-07-16 06:00:00
# 2020-07-16 07:00:00
# 2020-07-16 08:00:00
# 2020-07-16 09:00:00
# 2020-07-16 10:00:00
# 2020-07-16 11:00:00
# 2020-07-16 12:00:00
# 2020-07-16 13:00:00
# 2020-07-16 14:00:00
# 2020-07-16 15:00:00
# 2020-07-16 16:00:00
# 2020-07-16 17:00:00
# 2020-07-16 18:00:00
# 2020-07-16 19:00:00
# 2020-07-16 20:00:00
# 2020-07-16 21:00:00
# 2020-07-16 22:00:00
# 2020-07-16 23:00:00
# ******************
# whole year
# whole month
# whole day
# 2023-07-04
# whole hour
# 2023-07-04 00:00:00
# 2023-07-04 01:00:00
# 2023-07-04 02:00:00
# 2023-07-04 03:00:00
# 2023-07-04 04:00:00
# 2023-07-04 05:00:00
# 2023-07-04 06:00:00
# 2023-07-04 07:00:00
# 2023-07-04 08:00:00
# ...
